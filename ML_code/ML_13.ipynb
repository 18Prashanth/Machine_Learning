# %% [markdown]
# #                            **Naive Bayes Classifier Algorithm**

# %%
import pandas as pd
data = pd.read_csv('/content/titanic-Nav.csv')
df = pd.DataFrame(data)
df.head()
# Out:
#    PassengerId                                               Name  Pclass  ... Cabin  Embarked  Survived
# 0            1                            Braund, Mr. Owen Harris       3  ...   NaN         S         0
# 1            2  Cumings, Mrs. John Bradley (Florence Briggs Th...       1  ...   C85         C         1
# 2            3                             Heikkinen, Miss. Laina       3  ...   NaN         S         1
# 3            4       Futrelle, Mrs. Jacques Heath (Lily May Peel)       1  ...  C123         S         1
# 4            5                           Allen, Mr. William Henry       3  ...   NaN         S         0
#
# [5 rows x 12 columns]

# %%
df.drop(['PassengerId', 'Name','SibSp','Parch','Ticket','Cabin','Embarked'], axis='columns',inplace=True)
df.head()
# Out:
#    Pclass     Sex   Age     Fare  Survived
# 0       3    male  22.0   7.2500         0
# 1       1  female  38.0  71.2833         1
# 2       3  female  26.0   7.9250         1
# 3       1  female  35.0  53.1000         1
# 4       3    male  35.0   8.0500         0

# %%
target = df.Survived
inputs = df.drop('Survived', axis = 'columns')

# %%
dummies = pd.get_dummies(inputs.Sex)
dummies.head(3)
# Out:
#    female   male
# 0   False   True
# 1    True  False
# 2    True  False

# %%
inputs = pd.concat([inputs, dummies], axis = 'columns')
inputs.head()
# Out:
#    Pclass     Sex   Age     Fare  female   male
# 0       3    male  22.0   7.2500   False   True
# 1       1  female  38.0  71.2833    True  False
# 2       3  female  26.0   7.9250    True  False
# 3       1  female  35.0  53.1000    True  False
# 4       3    male  35.0   8.0500   False   True

# %%
inputs.drop('Sex', axis='columns', inplace= True)
inputs.head()
# Out:
#    Pclass   Age     Fare  female   male
# 0       3  22.0   7.2500   False   True
# 1       1  38.0  71.2833    True  False
# 2       3  26.0   7.9250    True  False
# 3       1  35.0  53.1000    True  False
# 4       3  35.0   8.0500   False   True

# %%
inputs.describe()
# Out:
#            Pclass         Age        Fare
# count  891.000000  714.000000  891.000000
# mean     2.308642   29.699118   32.204208
# std      0.836071   14.526497   49.693429
# min      1.000000    0.420000    0.000000
# 25%      2.000000   20.125000    7.910400
# 50%      3.000000   28.000000   14.454200
# 75%      3.000000   38.000000   31.000000
# max      3.000000   80.000000  512.329200

# %%
inputs.shape
# Out:
# (891, 5)

# %%
inputs.columns[inputs.isna().any()]
# Out:
# Index(['Age'], dtype='object')

# %%
inputs.Age[:10]
# Out:
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# 5     NaN
# 6    54.0
# 7     2.0
# 8    27.0
# 9    14.0
# Name: Age, dtype: float64

# %%
inputs.Age = inputs.Age.fillna(inputs.Age.mean())
inputs.head(10)
# Out:
#    Pclass        Age     Fare  female   male
# 0       3  22.000000   7.2500   False   True
# 1       1  38.000000  71.2833    True  False
# 2       3  26.000000   7.9250    True  False
# 3       1  35.000000  53.1000    True  False
# 4       3  35.000000   8.0500   False   True
# 5       3  29.699118   8.4583   False   True
# 6       1  54.000000  51.8625   False   True
# 7       3   2.000000  21.0750   False   True
# 8       3  27.000000  11.1333    True  False
# 9       2  14.000000  30.0708    True  False

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(inputs, target, test_size=0.2)

# %%
len(X_train)
# Out:
# 712

# %%
len(X_test)
# Out:
# 179

# %%
len(inputs)
# Out:
# 891

# %%
from sklearn.naive_bayes import GaussianNB
model = GaussianNB()

# %%
model.fit(X_train,y_train)
# Out:
# GaussianNB()

# %%
model.score(X_test, y_test)
# Out:
# 0.7206703910614525

# %%
X_test[:10]
# Out:
#      Pclass        Age     Fare  female   male
# 95        3  29.699118   8.0500   False   True
# 189       3  36.000000   7.8958   False   True
# 870       3  26.000000   7.8958   False   True
# 162       3  26.000000   7.7750   False   True
# 885       3  39.000000  29.1250    True  False
# 784       3  25.000000   7.0500   False   True
# 290       1  26.000000  78.8500    True  False
# 815       1  29.699118   0.0000   False   True
# 237       2   8.000000  26.2500    True  False
# 283       3  19.000000   8.0500   False   True

# %%
y_test[:10]
# Out:
# 95     0
# 189    0
# 870    0
# 162    0
# 885    0
# 784    0
# 290    1
# 815    0
# 237    1
# 283    1
# Name: Survived, dtype: int64

# %%
model.predict(X_test[:10])
# Out:
# array([0, 0, 0, 0, 1, 0, 1, 0, 1, 0])

# %%
model.predict_proba(X_test[:10])
# Out:
# array([[0.99300311, 0.00699689],
#        [0.99319641, 0.00680359],
#        [0.9927062 , 0.0072938 ],
#        [0.9927009 , 0.0072991 ],
#        [0.04972949, 0.95027051],
#        [0.99256366, 0.00743634],
#        [0.00103372, 0.99896628],
#        [0.94139241, 0.05860759],
#        [0.01446006, 0.98553994],
#        [0.99174438, 0.00825562]])
